# %% [markdown]
# # Sales Analysis

# %% [markdown]
# > Using Python, Pandas, Numpy & Matplotlib to analyze the sales data and answer business questions.

# %% [markdown]
# **Data Dictionary**
#
# 1. Row ID - Unique ID for each row.
# 2. Order ID - Unique Order ID for each Customer.
# 3. Order Date - Order Date of the product.
# 4. Ship Date - Shipping Date of the Product.
# 5. Ship Mode - Shipping Mode specified by the Customer.
# 6. Customer ID - Unique ID to identify each Customer.
# 7. Customer Name - Name of the Customer.
# 8. Segment - The segment where the Customer belongs.
# 9. Country - Country of residence of the Customer.
# 10. City - City of residence of of the Customer.
# 11. State - State of residence of the Customer.
# 12. Postal Code - Postal Code of every Customer.
# 13. Region - Region where the Customer belong.
# 14. Product ID - Unique ID of the Product.
# 15. Category - Category of the product ordered.
# 16. Sub-Category - Sub-Category of the product ordered.
# 17. Product Name - Name of the Product
# 18. Sales - Sales of the Product.
# 19. Quantity - Quantity of the Product.
# 20. Discount - Discount provided.
# 21. Profit - Profit/Loss incurred.

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Get the data

# %%
sales = pd.read_csv("Dataset/Superstore.csv",encoding='latin1')
sales.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Removing Unnecessary Columns

# %%
sales.drop('Row ID',axis=1,inplace=True)

# %%
sales.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
sales.shape
# Out:
# (9994, 20)

# %%
for columns in sales.columns:
    print(columns)
# Out:
# Order ID
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# Country
# City
# State
# Postal Code
# Region
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit

# %% [markdown]
# ## Get information about data

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
sales.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Check for Null values

# %%
sales.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### Convert the data type

# %%
sales['Order Date']=pd.to_datetime(sales['Order Date'])
sales['Ship Date']=pd.to_datetime(sales['Ship Date'])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %% [markdown]
# ### Create Month-Year and Year column from Order Date

# %%
sales['Year'] = sales['Order Date'].dt.year

# %%
sales['Month-Year'] = sales['Order Date'].apply(lambda x: x.strftime('%Y-%m'))
sales.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Group sales by months

# %%
sales_by_month = sales.groupby('Month-Year').sum()['Sales'].reset_index()

# %% [markdown]
# ## Visualization and Analysis

# %% [markdown]
# ### Visualization of sales treands by months

# %%
fig,ax = plt.subplots(figsize=(16,8))
ax.plot(sales_by_month['Month-Year'],sales_by_month['Sales'],color='salmon')
ax.set(title='Sales Trends by Months',
       xlabel='Sales Date',
       ylabel='Sales')
plt.xticks(rotation='90');

# %%
fig,ax = plt.subplots(figsize=(16,8))
ax.bar(sales_by_month['Month-Year'],sales_by_month['Sales'],color='lightblue')
ax.set(title='Sales Trends by Months',
       xlabel='Sales Date',
       ylabel='Sales')
plt.xticks(rotation='90');

# %% [markdown]
# ### Total sales chart by the year

# %%
sns.set_style('whitegrid')
sns.barplot(x='Year',y='Sales',data=sales.reset_index(), palette='rainbow')
plt.xticks(rotation = 'vertical')
plt.title('Total sales chart by the year');

# %% [markdown]
# ### Most profitable products

# %%
profitable_products = pd.DataFrame(sales.groupby(['Product Name']).sum()['Profit'])
profitable_products = profitable_products.sort_values(by=['Profit'], ascending = False)
profitable_products[:10]
# Out:
#                                                         Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Bind...   7753.0390
# Hewlett Packard LaserJet 3310 Copier                 6983.8836
# Canon PC1060 Personal Laser Copier                   4570.9347
# HP Designjet T520 Inkjet Large Format Printer -...   4094.9766
# Ativa V4110MDD Micro-Cut Shredder                    3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta     3717.9714
# Plantronics Savi W720 Multi-Device Wireless Hea...   3696.2820
# Ibico EPK-21 Electric Binding System                 3345.2823
# Zebra ZM400 Thermal Label Printer                    3343.5360

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(14,8))
sns.barplot(x='Product Name',y='Profit',data=profitable_products[:10].reset_index(),palette="rainbow")
plt.xticks(rotation = 'vertical')
plt.title('Most Profitable Products');

# %% [markdown]
# ### Most Selling Products by Sales

# %%
products_sales = pd.DataFrame(sales.groupby('Product Name').sum()['Sales'])
products_sales = products_sales.sort_values('Sales',ascending=False)
products_sales
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479
# ...                                                       ...
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set      7.700
# Grip Seal Envelopes                                     7.072
# Xerox 20                                                6.480
# Avery 5                                                 5.760
# Eureka Disposable Bags for Sanitaire Vibra Groo...      1.624
#
# [1850 rows x 1 columns]

# %% [markdown]
# ### Top 10 products by sales

# %%
product_sales = products_sales[:10]
product_sales
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479
# GBC Ibimaster 500 Manual ProClick Binding System    19024.500
# Hewlett Packard LaserJet 3310 Copier                18839.686
# HP Designjet T520 Inkjet Large Format Printer -...  18374.895
# GBC DocuBind P400 Electric Binding System           17965.068
# High Speed Automatic Electric Letter Opener         17030.312

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(14,8))
sns.barplot(x='Product Name',y='Sales',data=product_sales.reset_index(),palette='rainbow')
plt.xticks(rotation = 'vertical')
plt.title('Top 10 products by sales');

# %% [markdown]
# ### Most Selling Products by Quantity

# %%
products_by_quantity = pd.DataFrame(sales.groupby('Product Name').sum()['Quantity'])
products_by_quantity = products_by_quantity.sort_values('Quantity',ascending=False)
products_by_quantity
# Out:
#                                                     Quantity
# Product Name
# Staples                                                  215
# Staple envelope                                          170
# Easy-staple paper                                        150
# Staples in misc. colors                                   86
# KI Adjustable-Height Table                                74
# ...                                                      ...
# Global Enterprise Series Seating Low-Back Swive...         1
# Xerox 20                                                   1
# Penpower WorldCard Pro Card Scanner                        1
# Bush Saratoga Collection 5-Shelf Bookcase, Hano...         1
# Boston 1900 Electric Pencil Sharpener                      1
#
# [1850 rows x 1 columns]

# %% [markdown]
# ### Top 10 selling Product by Quantity

# %%
boughts = products_by_quantity[:10]
boughts
# Out:
#                                                     Quantity
# Product Name
# Staples                                                  215
# Staple envelope                                          170
# Easy-staple paper                                        150
# Staples in misc. colors                                   86
# KI Adjustable-Height Table                                74
# Avery Non-Stick Binders                                   71
# Storex Dura Pro Binders                                   71
# GBC Premium Transparent Covers with Diagonal Li...        67
# Situations Contoured Folding Chairs, 4/Set                64
# Staple-based wall hangings                                62

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(14,8))
sns.barplot(x='Product Name',y='Quantity',data=boughts.reset_index(),palette='rainbow')
plt.xticks(rotation = 'vertical')
plt.title('Top selling products');

# %% [markdown]
# ### Most used  ship modes

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.countplot(sales['Ship Mode'],palette='rainbow')
plt.title('Most used Ship Modes');
# Out:
# C:\Users\lenovo\Data_Science\New_folder\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Distribution of Shiping Modes

# %%
ship_mode = pd.DataFrame(sales['Ship Mode'].value_counts()).reset_index()
ship_mode.head()
# Out:
#             index  Ship Mode
# 0  Standard Class       5968
# 1    Second Class       1945
# 2     First Class       1538
# 3        Same Day        543

# %%
ship_mode = ship_mode.rename({'index': 'Ship Mode', 'Ship Mode': 'count'}, axis=1)
ship_mode.head()
# Out:
#         Ship Mode  count
# 0  Standard Class   5968
# 1    Second Class   1945
# 2     First Class   1538
# 3        Same Day    543

# %%
fig = plt.figure(figsize =(15, 7))
plt.pie(ship_mode['count'], labels = ship_mode['Ship Mode'])
plt.title('Distribution of Shipping modes');

# %% [markdown]
# ### Visualize the 'Category' column from the Shipmode column dataset standpoints

# %%
sns.set_style('whitegrid')
category_hist = sns.FacetGrid(sales, col='Ship Mode', palette='rainbow')
category_hist.map(plt.hist, 'Category');

# %% [markdown]
# ### Most sold Category

# %%
sales.groupby(['Category','Sales']).sum()
# Out:
#                       Postal Code  Quantity  Discount     Profit  Year
# Category   Sales
# Furniture  1.892            60653         1       0.6    -0.9933  2017
#            1.988            76106         1       0.6    -1.4413  2017
#            2.032            60653         1       0.6    -1.3208  2017
#            2.328           154082         4       1.2    -1.5132  4032
#            2.784            32303         2       0.2     0.4176  2017
# ...                           ...       ...       ...        ...   ...
# Technology 10499.970        19711         3       0.0  5039.9856  2017
#            11199.968        10024         4       0.2  3919.9888  2017
#            13999.960        98115         4       0.0  6719.9808  2017
#            17499.950        47905         5       0.0  8399.9760  2016
#            22638.480        32216         6       0.5 -1811.0784  2014
#
# [6247 rows x 5 columns]

# %% [markdown]
# ### Most profitable product categories and sub-categories

# %%
cateory_by_profit = pd.DataFrame(sales.groupby(['Category','Sub-Category']).sum()['Profit'])

# %%
cateory_by_profit.sort_values(['Profit'],ascending=False)
# Out:
#                                   Profit
# Category        Sub-Category
# Technology      Copiers       55617.8249
#                 Phones        44515.7306
#                 Accessories   41936.6357
# Office Supplies Paper         34053.5693
#                 Binders       30221.7633
# Furniture       Chairs        26590.1663
# Office Supplies Storage       21278.8264
#                 Appliances    18138.0054
# Furniture       Furnishings   13059.1436
# Office Supplies Envelopes      6964.1767
#                 Art            6527.7870
#                 Labels         5546.2540
# Technology      Machines       3384.7569
# Office Supplies Fasteners       949.5182
#                 Supplies      -1189.0995
# Furniture       Bookcases     -3472.5560
#                 Tables       -17725.4811

# %% [markdown]
# ### Most profitable Category

# %%
profitable_category = pd.DataFrame(sales.groupby(['Category']).sum(['Profit']))
profitable_category.sort_values(by=["Profit"],inplace=True,ascending=False)
profitable_category
# Out:
#                  Postal Code        Sales  Quantity  Discount       Profit  \
# Category
# Technology         102603754  836154.0330      6939    244.40  145454.9481
# Office Supplies    330772872  719047.0320     22906    947.80  122490.8008
# Furniture          118196026  741999.7953      8028    368.89   18451.2728
#
#                      Year
# Category
# Technology        3723057
# Office Supplies  12146743
# Furniture         4275328

# %%
plt.figure(figsize=(15, 6))
plt.bar(sales['Category'],sales['Sales'])
plt.xticks(size=8)
plt.title('Most Profitable Category');

# %% [markdown]
# ### Top 10 Customers

# %%
data10 = sales.sort_values('Profit',ascending=False).head(10)[['Order ID','Customer Name','Profit']]
data10
# Out:
#             Order ID         Customer Name     Profit
# 6826  CA-2016-118689          Tamara Chand  8399.9760
# 8153  CA-2017-140151          Raymond Buch  6719.9808
# 4190  CA-2017-166709          Hunter Lopez  5039.9856
# 9039  CA-2016-117121         Adrian Barton  4946.3700
# 4098  CA-2014-116904          Sanjit Chand  4630.4755
# 2623  CA-2017-127180          Tom Ashbrook  3919.9888
# 509   CA-2015-145352  Christopher Martinez  3177.4750
# 8488  CA-2016-158841          Sanjit Engle  2799.9840
# 7666  US-2016-140158         Daniel Raglin  2591.9568
# 6520  CA-2017-138289           Andy Reiter  2504.2216

# %% [markdown]
# ### Most selling Segments

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,8.5))
sns.countplot(sales['Segment'],palette='rainbow')
plt.title('Most selling Segments');
# Out:
# C:\Users\lenovo\Data_Science\New_folder\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Segments by Quantity

# %%
by_segment = pd.DataFrame(sales.groupby('Segment').sum()['Quantity'])
by_segment = by_segment.sort_values('Quantity',ascending=False)
by_segment
# Out:
#              Quantity
# Segment
# Consumer        19521
# Corporate       11608
# Home Office      6744

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,8.5))
sns.barplot(x='Segment',y='Quantity',data=by_segment.reset_index(),palette='rainbow')
plt.title('Segments by Qunatity');

# %% [markdown]
# ### Segments by profit

# %%
by_segment_p = pd.DataFrame(sales.groupby('Segment').sum()['Profit'])
by_segment_p = by_segment_p.sort_values('Profit',ascending=False)
by_segment_p
# Out:
#                   Profit
# Segment
# Consumer     134119.2092
# Corporate     91979.1340
# Home Office   60298.6785

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,8.5))
sns.barplot(x='Segment',y='Profit',data=by_segment_p.reset_index(),palette='rainbow')
plt.title("Segments by Profit");

# %% [markdown]
# ### Top  15 city by sales

# %%
cities = pd.DataFrame(sales.groupby('City').sum()['Sales'])
cities.sort_values('Sales',inplace=True, ascending=False)
cities.head(15)
# Out:
#                      Sales
# City
# New York City  256368.1610
# Los Angeles    175851.3410
# Seattle        119540.7420
# San Francisco  112669.0920
# Philadelphia   109077.0130
# Houston         64504.7604
# Chicago         48539.5410
# San Diego       47521.0290
# Jacksonville    44713.1830
# Springfield     43054.3420
# Detroit         42446.9440
# Columbus        38706.2430
# Newark          28576.1190
# Columbia        25283.3240
# Lafayette       25036.2000

# %%
cities = cities.sort_values(by = 'Sales',ascending = False)[1:16]
cities['Sales'].plot(kind='pie',autopct='%1.1f%%',figsize=(14,7))
plt.title('10 Countries with most sales');

# %% [markdown]
# ### Sub - Categories by Sales

# %%
by_sales = pd.DataFrame(sales.groupby('Sub-Category').sum()['Sales'])
by_sales.sort_values('Sales',inplace=True, ascending=False)
by_sales
# Out:
#                     Sales
# Sub-Category
# Phones        330007.0540
# Chairs        328449.1030
# Storage       223843.6080
# Tables        206965.5320
# Binders       203412.7330
# Machines      189238.6310
# Accessories   167380.3180
# Copiers       149528.0300
# Bookcases     114879.9963
# Appliances    107532.1610
# Furnishings    91705.1640
# Paper          78479.2060
# Supplies       46673.5380
# Art            27118.7920
# Envelopes      16476.4020
# Labels         12486.3120
# Fasteners       3024.2800

# %% [markdown]
# ### Discounts by Sub-Categories

# %%
by_discount = pd.DataFrame(sales.groupby('Sub-Category').sum()['Discount'])
by_discount.sort_values('Discount',inplace =True,ascending=False)
by_discount
# Out:
#               Discount
# Sub-Category
# Binders         567.00
# Phones          137.40
# Furnishings     132.40
# Chairs          105.00
# Paper           102.60
# Tables           83.35
# Appliances       77.60
# Storage          63.20
# Accessories      60.80
# Art              59.60
# Bookcases        48.14
# Machines         35.20
# Labels           25.00
# Envelopes        20.40
# Fasteners        17.80
# Supplies         14.60
# Copiers          11.00
